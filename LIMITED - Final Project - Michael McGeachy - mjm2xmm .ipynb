# %%
#Michael McGeachy - mjm2xmm - Final DSS Project
#Limits were put in display functions for this submission to make it easier to grade. both are uploaded for transparency

import os
import json
import pymongo
import pyspark.pandas as pd  # This uses Koalas that is included in PySpark version 3.2 or newer.
from pyspark.sql.functions import col
from pyspark.sql.types import StructType, StructField, StringType, TimestampType, BinaryType
from pyspark.sql.types import ByteType, ShortType, IntegerType, LongType, FloatType, DecimalType

# %% [markdown]
# #### 2.0. Instantiate Global Variables

# %%
# Azure MySQL Server Connection Information ###################
jdbc_hostname = "ds2000-mjm"
jdbc_port = 3306
src_database = "sakila_dw"

connection_properties = {
  "user" : "mmcgeachy",
  "password" : "Jack2020!",
  "driver" : "org.mariadb.jdbc.Driver"
}

# MongoDB Atlas Connection Information ########################
atlas_cluster_name = "cluster0.wrb1goe"
atlas_database_name = "sakila_dw"
atlas_user_name = "mjm2xmm"
atlas_password = "mjm2xmm"

# Data Files (JSON) Information ###############################
dst_database = "sakila_dlh"

base_dir = "dbfs:/FileStore/final_data"
database_dir = f"{base_dir}/{dst_database}"

data_dir = f"{base_dir}/rentals"
batch_dir = f"{data_dir}/batch"
stream_dir = f"{data_dir}/stream"

orders_stream_dir = f"{stream_dir}/rental"
payments_stream_dir = f"{stream_dir}/payments"
#inventory_trans_stream_dir = f"{stream_dir}/inventory_transactions"

orders_output_bronze = f"{database_dir}/fact_orders/bronze"
orders_output_silver = f"{database_dir}/fact_orders/silver"
orders_output_gold   = f"{database_dir}/fact_orders/gold"

purchase_orders_output_bronze = f"{database_dir}/fact_purchase_orders/bronze"
purchase_orders_output_silver = f"{database_dir}/fact_purchase_orders/silver"
purchase_orders_output_gold   = f"{database_dir}/fact_purchase_orders/gold"

inventory_trans_output_bronze = f"{database_dir}/fact_inventory_transactions/bronze"
inventory_trans_output_silver = f"{database_dir}/fact_inventory_transactions/silver"
inventory_trans_output_gold   = f"{database_dir}/fact_inventory_transactions/gold"

# Delete the Streaming Files ################################## 
dbutils.fs.rm(f"{database_dir}/fact_orders", True) 
dbutils.fs.rm(f"{database_dir}/fact_purchase_orders", True) 
dbutils.fs.rm(f"{database_dir}/fact_inventory_transactions", True)

# Delete the Database Files ###################################
dbutils.fs.rm(database_dir, True)
# Out:
# True

# %% [markdown]
# #### 3.0. Define Global Functions

# %%
##################################################################################################################
# Use this Function to Fetch a DataFrame from the MongoDB Atlas database server Using PyMongo.
##################################################################################################################
def get_mongo_dataframe(user_id, pwd, cluster_name, db_name, collection, conditions, projection, sort):
    '''Create a client connection to MongoDB'''
    mongo_uri = f"mongodb+srv://{user_id}:{pwd}@{cluster_name}.mongodb.net/{db_name}"
    
    client = pymongo.MongoClient(mongo_uri)

    '''Query MongoDB, and fill a python list with documents to create a DataFrame'''
    db = client[db_name]
    if conditions and projection and sort:
        dframe = pd.DataFrame(list(db[collection].find(conditions, projection).sort(sort)))
    elif conditions and projection and not sort:
        dframe = pd.DataFrame(list(db[collection].find(conditions, projection)))
    else:
        dframe = pd.DataFrame(list(db[collection].find()))

    client.close()
    
    return dframe

##################################################################################################################
# Use this Function to Create New Collections by Uploading JSON file(s) to the MongoDB Atlas server.
##################################################################################################################
def set_mongo_collection(user_id, pwd, cluster_name, db_name, src_file_path, json_files):
    '''Create a client connection to MongoDB'''
    mongo_uri = f"mongodb+srv://{user_id}:{pwd}@{cluster_name}.mongodb.net/{db_name}"
    client = pymongo.MongoClient(mongo_uri)
    db = client[db_name]
    
    '''Read in a JSON file, and Use It to Create a New Collection'''
    for file in json_files:
        db.drop_collection(file)
        json_file = os.path.join(src_file_path, json_files[file])
        with open(json_file, 'r') as openfile:
            json_object = json.load(openfile)
            file = db[file]
            result = file.insert_many(json_object)

    client.close()
    
    return result

# %% [markdown]
# ### Section II: Populate Dimensions by Ingesting Reference (Cold-path) Data
# #### 1.0. Fetch Reference Data From an Azure MySQL Database
# ##### 1.1. Create a New Databricks Metadata Database.

# %%
# %sql
DROP DATABASE IF EXISTS sakila_dlh CASCADE;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
CREATE DATABASE IF NOT EXISTS sakila_dlh
COMMENT "DS-2002 Final Project Database"
LOCATION "dbfs:/FileStore/final_data/sakila_dlh"
WITH DBPROPERTIES (contains_pii = true, purpose = "DS-2002 Final Project");
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ##### 1.2. Create a New Table that Sources Date Dimension Data from a Table in an Azure MySQL database.

# %%
# %sql
CREATE OR REPLACE TEMPORARY VIEW view_date
USING org.apache.spark.sql.jdbc
OPTIONS (
  url "jdbc:mysql://ds2000-mjm.mysql.database.azure.com:3306/sakila_dw", --Replace with your Server Name
  dbtable "dim_date",
  user "mmcgeachy",    
  password "Jack2020!" 
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# Dim Date table from MySQL

# %sql
USE DATABASE sakila_dlh;

CREATE OR REPLACE TABLE sakila_dlh.dim_date
COMMENT "Date Dimension Table"
LOCATION "dbfs:/FileStore/final_data/sakila_dlh/dim_date"
AS SELECT * FROM view_date
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
DESCRIBE EXTENDED sakila_dlh.dim_date;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>date_key</td><td>int</td><td>null</td></tr><tr><td>full_date</td><td>date</td><td>null</td></tr><tr><td>date_name</td><td>varchar(11)</td><td>null</td></tr><tr><td>date_name_us</td><td>varchar(11)</td><td>null</td></tr><tr><td>date_name_eu</td><td>varchar(11)</td><td>null</td></tr><tr><td>day_of_week</td><td>int</td><td>null</td></tr><tr><td>day_name_of_week</td><td>varchar(10)</td><td>null</td></tr><tr><td>day_of_month</td><td>int</td><td>null</td></tr><tr><td>day_of_year</td><td>int</td><td>null</td></tr><tr><td>weekday_weekend</td><td>varchar(10)</td><td>null</td></tr><tr><td>week_of_year</td><td>int</td><td>null</td></tr><tr><td>month_name</td><td>varchar(10)</td><td>null</td></tr><tr><td>month_of_year</td><td>int</td><td>null</td></tr><tr><td>is_last_day_of_month</td><td>varchar(1)</td><td>null</td></tr><tr><td>calendar_quarter</td><td>int</td><td>null</td></tr><tr><td>calendar_year</td><td>int</td><td>null</td></tr><tr><td>calendar_year_month</td><td>varchar(10)</td><td>null</td></tr><tr><td>calendar_year_qtr</td><td>varchar(10)</td><td>null</td></tr><tr><td>fiscal_month_of_year</td><td>int</td><td>null</td></tr><tr><td>fiscal_quarter</td><td>int</td><td>null</td></tr><tr><td>fiscal_year</td><td>int</td><td>null</td></tr><tr><td>fiscal_year_month</td><td>varchar(10)</td><td>null</td></tr><tr><td>fiscal_year_qtr</td><td>varchar(10)</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Delta Statistics Columns</td><td></td><td></td></tr><tr><td>Column Names</td><td>month_of_year, weekday_weekend, date_name_us, day_of_week, date_key, calendar_quarter, calendar_year_month, date_name_eu, date_name, fiscal_quarter, is_last_day_of_month, day_of_month, month_name, calendar_year_qtr, fiscal_year_qtr, full_date, fiscal_year_month, fiscal_month_of_year, calendar_year, day_name_of_week, day_of_year, week_of_year, fiscal_year</td><td></td></tr><tr><td>Column Selection Method</td><td>first-32</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>spark_catalog</td><td></td></tr><tr><td>Database</td><td>sakila_dlh</td><td></td></tr><tr><td>Table</td><td>dim_date</td><td></td></tr><tr><td>Created Time</td><td>Thu Dec 07 23:10:46 UTC 2023</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark 3.5.0</td><td></td></tr><tr><td>Type</td><td>EXTERNAL</td><td></td></tr><tr><td>Comment</td><td>Date Dimension Table</td><td></td></tr><tr><td>Location</td><td>dbfs:/FileStore/final_data/sakila_dlh/dim_date</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>root</td><td></td></tr><tr><td>Table Properties</td><td>[delta.minReaderVersion=1,delta.minWriterVersion=2]</td><td></td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM sakila_dlh.dim_date LIMIT 5
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date_key</th><th>full_date</th><th>date_name</th><th>date_name_us</th><th>date_name_eu</th><th>day_of_week</th><th>day_name_of_week</th><th>day_of_month</th><th>day_of_year</th><th>weekday_weekend</th><th>week_of_year</th><th>month_name</th><th>month_of_year</th><th>is_last_day_of_month</th><th>calendar_quarter</th><th>calendar_year</th><th>calendar_year_month</th><th>calendar_year_qtr</th><th>fiscal_month_of_year</th><th>fiscal_quarter</th><th>fiscal_year</th><th>fiscal_year_month</th><th>fiscal_year_qtr</th></tr></thead><tbody><tr><td>20000101</td><td>2000-01-01</td><td>2000/01/01</td><td>01/01/2000</td><td>01/01/2000</td><td>7</td><td>Saturday</td><td>1</td><td>1</td><td>Weekend</td><td>52</td><td>January</td><td>1</td><td>N</td><td>1</td><td>2000</td><td>2000-01</td><td>2000Q1</td><td>7</td><td>3</td><td>2000</td><td>2000-07</td><td>2000Q3</td></tr><tr><td>20000102</td><td>2000-01-02</td><td>2000/01/02</td><td>01/02/2000</td><td>02/01/2000</td><td>1</td><td>Sunday</td><td>2</td><td>2</td><td>Weekend</td><td>52</td><td>January</td><td>1</td><td>N</td><td>1</td><td>2000</td><td>2000-01</td><td>2000Q1</td><td>7</td><td>3</td><td>2000</td><td>2000-07</td><td>2000Q3</td></tr><tr><td>20000103</td><td>2000-01-03</td><td>2000/01/03</td><td>01/03/2000</td><td>03/01/2000</td><td>2</td><td>Monday</td><td>3</td><td>3</td><td>Weekday</td><td>1</td><td>January</td><td>1</td><td>N</td><td>1</td><td>2000</td><td>2000-01</td><td>2000Q1</td><td>7</td><td>3</td><td>2000</td><td>2000-07</td><td>2000Q3</td></tr><tr><td>20000104</td><td>2000-01-04</td><td>2000/01/04</td><td>01/04/2000</td><td>04/01/2000</td><td>3</td><td>Tuesday</td><td>4</td><td>4</td><td>Weekday</td><td>1</td><td>January</td><td>1</td><td>N</td><td>1</td><td>2000</td><td>2000-01</td><td>2000Q1</td><td>7</td><td>3</td><td>2000</td><td>2000-07</td><td>2000Q3</td></tr><tr><td>20000105</td><td>2000-01-05</td><td>2000/01/05</td><td>01/05/2000</td><td>05/01/2000</td><td>4</td><td>Wednesday</td><td>5</td><td>5</td><td>Weekday</td><td>1</td><td>January</td><td>1</td><td>N</td><td>1</td><td>2000</td><td>2000-01</td><td>2000Q1</td><td>7</td><td>3</td><td>2000</td><td>2000-07</td><td>2000Q3</td></tr></tbody></table></div>

# %% [markdown]
# ##### 1.3. Create a New Table that Sources Product Dimension Data from an Azure MySQL database.

# %%
# %sql
-- Create a Temporary View named "view_product" that extracts data from your MySQL Northwind database.

CREATE OR REPLACE TEMPORARY VIEW view_staff
USING org.apache.spark.sql.jdbc
OPTIONS (
  url "jdbc:mysql://ds2000-mjm.mysql.database.azure.com:3306/sakila_dw", --Replace with your Server Name
  dbtable "dim_staff",
  user "mmcgeachy",    --Replace with your User Name
  password "Jack2020!"  --Replace with you password
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
USE DATABASE sakila_dlh;

-- Create a new table named "northwind_dlh.dim_product" using data from the view named "view_product"

CREATE OR REPLACE TABLE sakila_dlh.dim_staff
COMMENT "Staff Table"
LOCATION "dbfs:/FileStore/final_data/sakila_dlh/dim_staff"
AS SELECT * FROM view_staff
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
DESCRIBE EXTENDED sakila_dlh.dim_staff;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>staff_id</td><td>bigint</td><td>null</td></tr><tr><td>first_name</td><td>varchar(65535)</td><td>null</td></tr><tr><td>last_name</td><td>varchar(65535)</td><td>null</td></tr><tr><td>email</td><td>varchar(65535)</td><td>null</td></tr><tr><td>store_id</td><td>bigint</td><td>null</td></tr><tr><td>username</td><td>varchar(65535)</td><td>null</td></tr><tr><td>password</td><td>varchar(65535)</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Delta Statistics Columns</td><td></td><td></td></tr><tr><td>Column Names</td><td>first_name, email, username, store_id, last_name, staff_id, password</td><td></td></tr><tr><td>Column Selection Method</td><td>first-32</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>spark_catalog</td><td></td></tr><tr><td>Database</td><td>sakila_dlh</td><td></td></tr><tr><td>Table</td><td>dim_staff</td><td></td></tr><tr><td>Created Time</td><td>Thu Dec 07 23:11:06 UTC 2023</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark 3.5.0</td><td></td></tr><tr><td>Type</td><td>EXTERNAL</td><td></td></tr><tr><td>Comment</td><td>Staff Table</td><td></td></tr><tr><td>Location</td><td>dbfs:/FileStore/final_data/sakila_dlh/dim_staff</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>root</td><td></td></tr><tr><td>Table Properties</td><td>[delta.minReaderVersion=1,delta.minWriterVersion=2]</td><td></td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM sakila_dlh.dim_staff LIMIT 5
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>staff_id</th><th>first_name</th><th>last_name</th><th>email</th><th>store_id</th><th>username</th><th>password</th></tr></thead><tbody><tr><td>1</td><td>Mike</td><td>Hillyer</td><td>Mike.Hillyer@sakilastaff.com</td><td>1</td><td>Mike</td><td>8cb2237d0679ca88db6464eac60da96345513964</td></tr><tr><td>2</td><td>Jon</td><td>Stephens</td><td>Jon.Stephens@sakilastaff.com</td><td>2</td><td>Jon</td><td></td></tr></tbody></table></div>

# %% [markdown]
# #### 2.0. Fetch Reference Data from a MongoDB Atlas Database
# ##### 2.1. View the Data Files on the Databricks File System

# %%
#Mongo Source for Payments Table

display(dbutils.fs.ls(batch_dir))  # '/dbfs/FileStore/final_data/rentals/batch'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/final_data/rentals/batch/payments.json</td><td>payments.json</td><td>1742725</td><td>1701374388000</td></tr><tr><td>dbfs:/FileStore/final_data/rentals/batch/rental.csv</td><td>rental.csv</td><td>803707</td><td>1701985689000</td></tr><tr><td>dbfs:/FileStore/final_data/rentals/batch/rental.json</td><td>rental.json</td><td>1525645</td><td>1701374754000</td></tr></tbody></table></div>

# %% [markdown]
# ##### 2.2. Create a New MongoDB Database, and Load JSON Data Into a New MongoDB Collection
# **NOTE:** The following cell **can** be run more than once because the **set_mongo_collection()** function **is** idempotent.

# %%
source_dir = '/dbfs/FileStore/final_data/rentals/batch'
json_files = {"payments" : 'payments.json'
            }

set_mongo_collection(atlas_user_name, atlas_password, atlas_cluster_name, atlas_database_name, source_dir, json_files)

# %% [markdown]
# ##### 2.3.1. Fetch Customer Dimension Data from the New MongoDB Collection

# %%
# %scala
import com.mongodb.spark._

val userName = "mjm2xmm"
val pwd = "mjm2xmm"
val clusterName = "cluster0.wrb1goe"
val atlas_uri = s"mongodb+srv://$userName:$pwd@$clusterName.mongodb.net/?retryWrites=true&w=majority"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">import com.mongodb.spark._
# userName: String = mjm2xmm
# pwd: String = mjm2xmm
# clusterName: String = cluster0.wrb1goe
# atlas_uri: String = mongodb+srv://mjm2xmm:mjm2xmm@cluster0.wrb1goe.mongodb.net/?retryWrites=true&amp;w=majority
# </div>

# %%
# %scala

val df_payments = spark.read.format("com.mongodb.spark.sql.DefaultSource")
.option("spark.mongodb.input.uri", atlas_uri)
.option("database", "sakila_dw")
.option("collection", "payments").load()
.select("payment_key","staff_id","rental_id","amount","payment_date")

display(df_payments.limit(100))

/*limit put in for grading practicality
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>payment_key</th><th>staff_id</th><th>rental_id</th><th>amount</th><th>payment_date</th></tr></thead><tbody><tr><td>1</td><td>1</td><td>76</td><td>2.99</td><td>2005-05-25 11:30:37</td></tr><tr><td>2</td><td>1</td><td>573</td><td>0.99</td><td>2005-05-28 10:35:23</td></tr><tr><td>3</td><td>1</td><td>1185</td><td>5.99</td><td>2005-06-15 00:54:12</td></tr><tr><td>4</td><td>2</td><td>1422</td><td>0.99</td><td>2005-06-15 18:02:53</td></tr><tr><td>5</td><td>2</td><td>1476</td><td>9.99</td><td>2005-06-15 21:08:46</td></tr><tr><td>6</td><td>1</td><td>1725</td><td>4.99</td><td>2005-06-16 15:18:57</td></tr><tr><td>7</td><td>1</td><td>2308</td><td>4.99</td><td>2005-06-18 08:41:48</td></tr><tr><td>8</td><td>2</td><td>2363</td><td>0.99</td><td>2005-06-18 13:33
</td><td>7459</td><td>5.99</td><td>2005-07-27 18:40:20</td></tr><tr><td>40</td><td>2</td><td>8230</td><td>5.99</td><td>2005-07-29 00:12:59</td></tr><tr><td>41</td><td>1</td><td>8598</td><td>2.99</td><td>2005-07-29 12:56:59</td></tr><tr><td>42</td><td>2</td><td>8705</td><td>5.99</td><td>2005-07-29 17:14:29</td></tr><tr><td>43</td><td>1</td><td>9031</td><td>4.99</td><td>2005-07-30 06:06:10</td></tr><tr><td>44</td><td>2</td><td>9236</td><td>10.99</td><td>2005-07-30 13:47:43</td></tr><tr><td>45</td><td>2</td><td>9248</td><td>0.99</td><td>2005-07-30 14:14:11</td> ...

# %%
# %scala
df_payments.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- payment_key: integer (nullable = true)
# -- staff_id: integer (nullable = true)
# -- rental_id: integer (nullable = true)
# -- amount: double (nullable = true)
# -- payment_date: string (nullable = true)
#
# </div>

# %% [markdown]
# ##### 2.3.2. Use the Spark DataFrame to Create a New Customer Dimension Table in the Databricks Metadata Database (northwind_dlh)

# %%
# %scala
df_payments.write.format("delta").mode("overwrite").saveAsTable("sakila_dlh.dim_payments")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
DESCRIBE EXTENDED sakila_dlh.dim_payments
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>payment_key</td><td>int</td><td>null</td></tr><tr><td>staff_id</td><td>int</td><td>null</td></tr><tr><td>rental_id</td><td>int</td><td>null</td></tr><tr><td>amount</td><td>double</td><td>null</td></tr><tr><td>payment_date</td><td>string</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Delta Statistics Columns</td><td></td><td></td></tr><tr><td>Column Names</td><td>rental_id, payment_date, amount, payment_key, staff_id</td><td></td></tr><tr><td>Column Selection Method</td><td>first-32</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>spark_catalog</td><td></td></tr><tr><td>Database</td><td>sakila_dlh</td><td></td></tr><tr><td>Table</td><td>dim_payments</td><td></td></tr><tr><td>Created Time</td><td>Thu Dec 07 23:12:11 UTC 2023</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark 3.5.0</td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Location</td><td>dbfs:/FileStore/final_data/sakila_dlh/dim_payments</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>root</td><td></td></tr><tr><td>Is_managed_location</td><td>true</td><td></td></tr><tr><td>Table Properties</td><td>[delta.minReaderVersion=1,delta.minWriterVersion=2]</td><td></td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM sakila_dlh.dim_payments LIMIT 5
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>payment_key</th><th>staff_id</th><th>rental_id</th><th>amount</th><th>payment_date</th></tr></thead><tbody><tr><td>1</td><td>1</td><td>76</td><td>2.99</td><td>2005-05-25 11:30:37</td></tr><tr><td>2</td><td>1</td><td>573</td><td>0.99</td><td>2005-05-28 10:35:23</td></tr><tr><td>3</td><td>1</td><td>1185</td><td>5.99</td><td>2005-06-15 00:54:12</td></tr><tr><td>4</td><td>2</td><td>1422</td><td>0.99</td><td>2005-06-15 18:02:53</td></tr><tr><td>5</td><td>2</td><td>1476</td><td>9.99</td><td>2005-06-15 21:08:46</td></tr></tbody></table></div>

# %% [markdown]
# #### 3.0. Fetch Data from a File System
# ##### 3.1. Use PySpark to Read From a CSV File

# %%
#File Source for Rental Table

rental_csv = f"{batch_dir}/rental.csv"

df_rental = spark.read.format('csv').options(header='true', inferSchema='true').load(rental_csv)
display(df_rental.limit(100))

#limit put in for practical grading
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>rental_id</th><th>rental_date</th><th>return_date</th></tr></thead><tbody><tr><td>1</td><td>2005-05-24T22:53:30Z</td><td>2005-05-26T22:04:30Z</td></tr><tr><td>2</td><td>2005-05-24T22:54:33Z</td><td>2005-05-28T19:40:33Z</td></tr><tr><td>3</td><td>2005-05-24T23:03:39Z</td><td>2005-06-01T22:12:39Z</td></tr><tr><td>4</td><td>2005-05-24T23:04:41Z</td><td>2005-06-03T01:43:41Z</td></tr><tr><td>5</td><td>2005-05-24T23:05:21Z</td><td>2005-06-02T04:33:21Z</td></tr><tr><td>6</td><td>2005
td><td>true</td></tr></tbody></table></div>

# %% [markdown]
# ### Section III: Integrate Reference Data with Real-Time Data
# #### 6.0. Use AutoLoader to Process Streaming (Hot Path) Orders Fact Data
# ##### 6.1. Bronze Table: Process 'Raw' JSON Data

# %%
# Uses 3 source files for fact table from streaming folder

(spark.readStream
 .format("cloudFiles")
 .option("cloudFiles.format", "json")
 .option("cloudFiles.schemaHints", "staff_id BIGINT")
 .option("cloudFiles.schemaHints", "first_name STRING")
 .option("cloudFiles.schemaHints", "last_name STRING")
 .option("cloudFiles.schemaHints", "rental_id BIGINT") 
 .option("cloudFiles.schemaHints", "amount DECIMAL")
 .option("cloudFiles.schemaHints", "rental_date_key BIGINT")
 .option("cloudFiles.schemaLocation", orders_output_bronze)
 .option("cloudFiles.inferColumnTypes", "true")
 .option("multiLine", "true")
 .load(orders_stream_dir)
 .createOrReplaceTempView("orders_raw_tempview"))

# %%
# %sql
/* Add Metadata for Traceability */
CREATE OR REPLACE TEMPORARY VIEW orders_bronze_tempview AS (
  SELECT *, current_timestamp() receipt_time, input_file_name() source_file
  FROM orders_raw_tempview
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SELECT * FROM orders_bronze_tempview limit 100

/* limit put for practical grading purposes
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>amount</th><th>first_name</th><th>last_name</th><th>rental_date_key</th><th>rental_id</th><th>staff_id</th><th>_rescued_data</th><th>receipt_time</th><th>source_file</th></tr></thead><tbody><tr><td>1.99</td><td>Mike</td><td>Hillyer</td><td>20050528</td><td>663</td><td>1</td><td>null</td><td>2023-12-07T23:17:45.502Z</td><td>dbfs:/FileStore/final_data/rentals/stream/rental/fact_orders_3.json</td></tr><tr><td>0.99</td><td>Jon</td><td>Stephens</td><td>20050528</td><td>664</td><td>2</td><td>null</td><td>2023-12-07T23:17:45.502Z</td><td>dbfs:/FileStore/final_data/rentals/stream/rental/fact_orders_3.json</td></tr><tr><td>4.99</td><td>Jon</td><td>Stephens</td><td>20050528</td><td>665</td><td>2</td><td>null</td><td>2023-12-07T23:17:45.502Z</td><td>dbfs:/FileStore/final_data/rentals/stream/rental/fact_orders_3.json</td></tr><tr><td>5.99</td><td>Mike</td><td>Hillyer</td><td>20050528</td><td>666</td><td>1</td><td>null</td><td>2023-12-07T23:17:45.502Z</td><td>dbfs:/FileStore/final_data/rentals/stream/rental/fact_orders_3.json</td></tr><tr><td>4.99</td><td>Jon</td><td>Stephens</td><td>20050528</td><td>667</td><td>2</td><td>null</td><td>2023-12-07T23:17:45.502Z</td><td>dbfs:/FileStore/final_data/rentals/stream/rental/fact_orders_3.json</td></tr><tr><td>2.99</td><td>Jon</td><td>Stephens</td><td>20050528</td><td>668</td><td>2</td><td>null</td><td>2023-12-07T23:17:45.502Z</td><td>dbfs:/FileStore/final_data/rentals/stream/rental/fact_orders_3.json</td></tr><tr><td>4.99</td><td>Jon</td><td>Stephens</td><td>20050528</td><td>669</td><td>2</td><td>null</td><td>2023-12-07T23:17:45.502Z</td><td>dbfs:/FileStore/final_data/rentals/stream/rental/fact_orders_3.json</td></tr><tr><td>6.99</td><td>Mike</td><td>Hillyer</td><td>20050528</td><td>670</td><td>1</td><td>null</td><td>2023-12-07T23:17:45.502Z</td><td>dbfs:/FileStore/final_data/rentals/stream/rental/fact_orders_3.json</td></tr><tr><td>2.99</td><td>Mike</td><td>Hillyer</td><td>20050528</td><td>671</td><td>1</td><td>null</td><td>2023-12-07T23:17:45.502Z</td><td>dbfs:/FileStore/final_data/rentals/stream/rental/fact_orders_3.json</td></tr><tr><td>6.99</td><td>Jon</td><td>Stephens</td><td>20050528</td><td>672</td><td>2</td><td>null</td><td>2023-12-07T23:17:45.502Z</td><td>dbfs:/FileStore/final_data/rentals/stream/rental/fact_orders_3.json</td></tr><tr><td>0.99</td><td>Mike</td><td>Hillyer</td><td>20050528</td><td>673</td><td>1</td><td>null</td><td>2023-12-07T23:17:45.502Z</td><td>dbfs:/FileStore/final_data/rentals/stream/rental/fact_orders_3.json</td></tr><tr><td>2.99</td><td>Mike</td><td>Hillyer</td><td>20050528</td><td>674</td><td>1</td><td>null</td><td>2023-12-07T23:17:45.502Z</td><td>dbfs:/FileStore/final_data/rentals/stream/rental/fact_orders_3.json</td></tr><tr><td>0.99</td><td>Mike</td><td>Hillyer</td><td>20050528</td><td>675</td><td>1</td><td>null</td><td>2023-12-07T23:17:45.502Z</td><td>dbfs:/FileStore/final_data/rentals/stream/rental/fact_orders_3.json</td></tr><tr><td>4.99</td><td>Jon</td><td>Stephens</td><td>20050528</td><td>676</td><td>2</td><td>null</td><td>2023-12-07T23:17:45.502Z</td><td>dbfs:/FileStore/final_data/rentals/stream/rental/fact_orders_3.json</td></tr><tr><td>7.99</td><td>Jon</td><td>Stephens</td><td>20050528</td><td>677</td><td>2</td><td>null</td><td>2023-12-07T23:17:45.502Z</td><td>dbfs:/FileStore/final_data/rentals/stream/rental/fact_orders_3.json</td></tr><tr><td>6.99</td><td>Jon</td><td>Stephens</td><td>20050528</td><td>678</td><td>2</td><td>null</td><td>2023-12-07T23:17:45.502Z</td><td>dbfs:/FileStore/final_data/rentals/stream/rental/fact_orders_3.json</td></tr><tr><td>4.99</td><td>Jon</td><td>Stephens</td><td>20050528</td><td>679</td><td>2</td><td>null</td><td>2023-12-07T23:17:45.502Z</td><td>dbfs:/FileStore/final_data/rentals/stream/rental/fact_orders_3.json</td></tr><tr><td>2.99</td><td>Jon</td><td>Stephens</td><td>20050528</td><td>680</td><td>2</td><t ...

# %%
(spark.table("orders_bronze_tempview")
      .writeStream
      .format("delta")
      .option("checkpointLocation", f"{orders_output_bronze}/_checkpoint")
      .outputMode("append")
      .table("fact_orders_bronze"))

# %% [markdown]
# ##### 6.2. Silver Table: Include Reference Data

# %%
(spark.readStream
  .table("fact_orders_bronze")
  .createOrReplaceTempView("orders_silver_tempview"))

# %%
# %sql
SELECT * FROM orders_silver_tempview limit 100 

/*limit put in place for practical reasons
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>amount</th><th>first_name</th><th>last_name</th><th>rental_date_key</th><th>rental_id</th><th>staff_id</th><th>_rescued_data</th><th>receipt_time</th><th>source_file</th></tr></thead><tbody><tr><td>1.99</td><td>Mike</td><td>Hillyer</td><td>20050528</td><td>663</td><td>1</td><td>null</td><td>2023-12-07T23:17:58.785Z</td><td>dbfs:/FileStore/final_data/rentals/stream/rental/fact_orders_3.json</td></tr><tr><td>0.99</td><td>Jon</td><td>Stephens</td><td>20050528</td><td>664</td><td>2</td><td>null</td><td>2023-12-07T23:17:58.785Z</td><td>dbfs:/FileStore/final_data/rentals/stream/rental/fact_orders_3.json</td></tr><tr><td>4.99</td><td>Jon</td><
td>Jon</td><td>Stephens</td><td>20050528</td><td>678</td><td>2</td><td>null</td><td>2023-12-07T23:17:58.785Z</td><td>dbfs:/FileStore/final_data/rentals/stream/rental/fact_orders_3.json</td></tr><tr><td>4.99</td><td>Jon</td><td>Stephens</td><td>20050528</td><td>679</td><td>2</td><td>null</td><td>2023-12-07T23:17:58.785Z</td><td>dbfs:/FileStore/final_data/rentals/stream/rental/fact_orders_3.json</td></tr><tr><td>2.99</td><td>Jon</td><td>Stephens</td><td>20050528</td><td>680</td><td>2</td><t ...

# %%
# %sql
DESCRIBE EXTENDED orders_silver_tempview
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>amount</td><td>double</td><td>null</td></tr><tr><td>first_name</td><td>string</td><td>null</td></tr><tr><td>last_name</td><td>string</td><td>null</td></tr><tr><td>rental_date_key</td><td>bigint</td><td>null</td></tr><tr><td>rental_id</td><td>bigint</td><td>null</td></tr><tr><td>staff_id</td><td>bigint</td><td>null</td></tr><tr><td>_rescued_data</td><td>string</td><td>null</td></tr><tr><td>receipt_time</td><td>timestamp</td><td>null</td></tr><tr><td>source_file</td><td>string</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
CREATE OR REPLACE TEMPORARY VIEW fact_orders_silver_tempview AS (
  SELECT o.rental_id,
      o.staff_id,
      o.rental_date_key,
      e.last_name AS employee_last_name,
      e.first_name AS employee_first_name,
      e.email AS employee_email,
      c.amount as payment,
      c.payment_date,
      r.rental_date,
      rd.day_name_of_week AS order_day_name_of_week,
      rd.day_of_month AS order_day_of_month,
      rd.weekday_weekend AS order_weekday_weekend,
      rd.month_name AS order_month_name,
      rd.calendar_quarter AS order_quarter,
      rd.calendar_year AS order_year
      

  FROM orders_silver_tempview AS o
  INNER JOIN sakila_dlh.dim_staff AS e
  ON e.staff_id = o.staff_id
  INNER JOIN sakila_dlh.dim_payments AS c
  ON c.rental_id = o.rental_id
  INNER JOIN sakila_dlh.dim_rental AS r
  ON r.rental_id = o.rental_id
  LEFT OUTER JOIN sakila_dlh.dim_date AS rd
  ON rd.date_key = o.rental_date_key
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
(spark.table("fact_orders_silver_tempview")
      .writeStream
      .format("delta")
      .option("checkpointLocation", f"{orders_output_silver}/_checkpoint")
      .outputMode("append")
      .table("fact_orders_silver"))

# %%
# %sql
SELECT * FROM fact_orders_silver LIMIT 5
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>rental_id</th><th>staff_id</th><th>rental_date_key</th><th>employee_last_name</th><th>employee_first_name</th><th>employee_email</th><th>payment</th><th>payment_date</th><th>rental_date</th><th>order_day_name_of_week</th><th>order_day_of_month</th><th>order_weekday_weekend</th><th>order_month_name</th><th>order_quarter</th><th>order_year</th></tr></thead><tbody><tr><td>663</td><td>1</td><td>20050528</td><td>Hillyer</td><td>Mike</td><td>Mike.Hillyer@sakilastaff.com</td><td>1.99</td><td>2005-05-28 21:23:02</td><td>2005-05-28T21:23:02Z</td><td>Saturday</td><td>28</td><td>Weekend</td><td>May</td><td>2</td><td>2005</td></tr><tr><td>664</td><td>2</td><td>20050528</td><td>Stephens</td><td>Jon</td><td>Jon.Stephens@sakilastaff.com</td><td>0.99</td><td>2005-05-28 21:31:08</td><td>2005-05-28T21:31:08Z</td><td>Saturday</td><td>28</td><td>Weekend</td><td>May</td><td>2</td><td>2005</td></tr><tr><td>665</td><td>2</td><td>20050528</td><td>Stephens</td><td>Jon</td><td>Jon.Stephens@sakilastaff.com</td><td>4.99</td><td>2005-05-28 21:38:39</td><td>2005-05-28T21:38:39Z</td><td>Saturday</td><td>28</td><td>Weekend</td><td>May</td><td>2</td><td>2005</td></tr><tr><td>666</td><td>1</td><td>20050528</td><td>Hillyer</td><td>Mike</td><td>Mike.Hillyer@sakilastaff.com</td><td>5.99</td><td>2005-05-28 21:48:51</td><td>2005-05-28T21:48:51Z</td><td>Saturday</td><td>28</td><td>Weekend</td><td>May</td><td>2</td><td>2005</td></tr><tr><td>667</td><td>2</td><td>20050528</td><td>Stephens</td><td>Jon</td><td>Jon.Stephens@sakilastaff.com</td><td>4.99</td><td>2005-05-28 21:49:02</td><td>2005-05-28T21:49:02Z</td><td>Saturday</td><td>28</td><td>Weekend</td><td>May</td><td>2</td><td>2005</td></tr></tbody></table></div>
# Databricks data profile. Run in Databricks to view.

# %%
# %sql
DESCRIBE EXTENDED sakila_dlh.fact_orders_silver
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>rental_id</td><td>bigint</td><td>null</td></tr><tr><td>staff_id</td><td>bigint</td><td>null</td></tr><tr><td>rental_date_key</td><td>bigint</td><td>null</td></tr><tr><td>employee_last_name</td><td>varchar(65535)</td><td>null</td></tr><tr><td>employee_first_name</td><td>varchar(65535)</td><td>null</td></tr><tr><td>employee_email</td><td>varchar(65535)</td><td>null</td></tr><tr><td>payment</td><td>double</td><td>null</td></tr><tr><td>payment_date</td><td>string</td><td>null</td></tr><tr><td>rental_date</td><td>timestamp</td><td>null</td></tr><tr><td>order_day_name_of_week</td><td>varchar(10)</td><td>null</td></tr><tr><td>order_day_of_month</td><td>int</td><td>null</td></tr><tr><td>order_weekday_weekend</td><td>varchar(10)</td><td>null</td></tr><tr><td>order_month_name</td><td>varchar(10)</td><td>null</td></tr><tr><td>order_quarter</td><td>int</td><td>null</td></tr><tr><td>order_year</td><td>int</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Delta Statistics Columns</td><td></td><td></td></tr><tr><td>Column Names</td><td>employee_email, employee_last_name, rental_date, rental_id, payment_date, employee_first_name, order_day_of_month, order_weekday_weekend, payment, order_year, order_month_name, rental_date_key, order_quarter, staff_id, order_day_name_of_week</td><td></td></tr><tr><td>Column Selection Method</td><td>first-32</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>spark_catalog</td><td></td></tr><tr><td>Database</td><td>sakila_dlh</td><td></td></tr><tr><td>Table</td><td>fact_orders_silver</td><td></td></tr><tr><td>Created Time</td><td>Thu Dec 07 23:25:12 UTC 2023</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark 3.5.0</td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Location</td><td>dbfs:/FileStore/final_data/sakila_dlh/fact_orders_silver</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>root</td><td></td></tr><tr><td>Is_managed_location</td><td>true</td><td></td></tr><tr><td>Table Properties</td><td>[delta.minReaderVersion=1,delta.minWriterVersion=2]</td><td></td></tr></tbody></table></div>

# %%
#gold table with query that shows sales and number of orders in June 2005 for each salesmen
# As for its business use, this would be good for comparing performance over a given time
# %sql
    SELECT   
          t.last_name AS staff_name,
          SUM(orders.payment) AS total_sales,
          COUNT(st.rental_id) AS numer_of_orders
    FROM sakila_dlh.fact_orders_silver AS orders 
    JOIN sakila_dlh.dim_rental st ON orders.rental_id=st.rental_id
    JOIN sakila_dlh.dim_staff t ON orders.staff_id=t.staff_id
    WHERE (orders.rental_date_key >= 20050601) and (orders.rental_date_key <= 20050630)
    GROUP BY t.last_name
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>staff_name</th><th>total_sales</th><th>numer_of_orders</th></tr></thead><tbody><tr><td>Stephens</td><td>997.5400000000018</td><td>246</td></tr><tr><td>Hillyer</td><td>1051.410000000002</td><td>259</td></tr></tbody></table></div>
